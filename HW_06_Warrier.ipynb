# %% [markdown]
# ## Author: Shruti Warrier
# ## Date: 3/30/20
# ## CS301-006, Professor Watson
# ## HW06 Solution
#
# The purpose of this assignment is to help students practice using Python to prepare their data sets for machine learning.
#
# link to the git repo:https://github.com/swarrier16/cs301_summaryTests

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Question 1 - Read in the data set and print the % empty values for each column. Are there any columns with missing values?

# %%
data_dir = '/Users/swarrier/Documents/CS301/groundhog.csv'
df = pd.read_csv(data_dir, index_col = 0)
df.head(15)
# Out:
#     Year Punxsutawney Phil  February Average Temperature  \
# 0   1886         No Record                           NaN
# 1   1887       Full Shadow                           NaN
# 2   1888       Full Shadow                           NaN
# 3   1889         No Record                           NaN
# 4   1890         No Shadow                           NaN
# 5   1891         No Record                           NaN
# 6   1892         No Record                           NaN
# 7   1893         No Record                           NaN
# 8   1894         No Record                           NaN
# 9   1895         No Record                         26.60
# 10  1896         No Record                         35.04
# 11  1897         No Record                         33.39
# 12  1898       Full Shadow                         35.37
# 13  1899         No Record                         25.50
# 14  1900       Full Shadow                         30.76
#
#     February Average Temperature (Northeast)  \
# ...

# %%
def get_percent_nans(df, column_name):
    null = df[column_name].isnull().sum()
    percent = null / len(df[column_name]) * 100
    
    return percent

for col in df.columns:
    print ('The \"{}\" column has {:.2f}% empty values'.format(col, get_percent_nans(df,col)))
# Out:
# The "Year" column has 0.00% empty values
# The "Punxsutawney Phil" column has 0.00% empty values
# The "February Average Temperature" column has 6.87% empty values
# The "February Average Temperature (Northeast)" column has 6.87% empty values
# The "February Average Temperature (Midwest)" column has 6.87% empty values
# The "February Average Temperature (Pennsylvania)" column has 6.87% empty values
# The "March Average Temperature" column has 6.87% empty values
# The "March Average Temperature (Northeast)" column has 6.87% empty values
# The "March Average Temperature (Midwest)" column has 6.87% empty values
# The "March Average Temperature (Pennsylvania)" column has 6.87% empty values

# %% [markdown]
# All the columns after Punxsutawney Phil have missing values. These columns include:
# - February Average Temperature
# - February Average Temperature (Northeast)
# - February Average Temperature (Midwest)
# - February Average Temperature (Pennsylvania)
# - March Average Temperature
# - March Average Temperature (Northeast)
# - March Average Temperature (Midwest)
# - March Average Temperature (Pennsylvania)

# %% [markdown]
# #### Question 2 - Create a new dataframe which is a copy of the orginal one. In this copy, replace the missing values in the data set using one of the discussed methods in class.

# %%
df2 = df.copy()
febAvg = df2['February Average Temperature'].mean()
febAvgNE = df2['February Average Temperature (Northeast)'].mean()
febAvgMW = df2['February Average Temperature (Midwest)'].mean()
febAvgPA = df2['February Average Temperature (Pennsylvania)'].mean()
marAvg = df2['March Average Temperature'].mean()
marAvgNE = df2['March Average Temperature (Northeast)'].mean()
marAvgMW = df2['March Average Temperature (Midwest)'].mean()
marAvgPA = df2['March Average Temperature (Pennsylvania)'].mean()

# %%
df2["February Average Temperature"] = df2["February Average Temperature"].fillna(febAvg)
df2["February Average Temperature (Northeast)"] = df2["February Average Temperature (Northeast)"].fillna(febAvgNE)
df2["February Average Temperature (Midwest)"] = df2["February Average Temperature (Midwest)"].fillna(febAvgMW)
df2["February Average Temperature (Pennsylvania)"] = df2["February Average Temperature (Pennsylvania)"].fillna(febAvgPA)
df2["March Average Temperature"] = df["March Average Temperature"].fillna(marAvg)
df2["March Average Temperature (Northeast)"] = df2["March Average Temperature (Northeast)"].fillna(marAvgNE)
df2["March Average Temperature (Midwest)"] = df2["March Average Temperature (Midwest)"].fillna(marAvgMW)
df2["March Average Temperature (Pennsylvania)"] = df2["March Average Temperature (Pennsylvania)"].fillna(marAvgPA)
df2.head(10)
# Out:
#    Year Punxsutawney Phil  February Average Temperature  \
# 0  1886         No Record                     33.802705
# 1  1887       Full Shadow                     33.802705
# 2  1888       Full Shadow                     33.802705
# 3  1889         No Record                     33.802705
# 4  1890         No Shadow                     33.802705
# 5  1891         No Record                     33.802705
# 6  1892         No Record                     33.802705
# 7  1893         No Record                     33.802705
# 8  1894         No Record                     33.802705
# 9  1895         No Record                     26.600000
#
#    February Average Temperature (Northeast)  \
# 0                                 22.693443
# 1                                 22.693443
# 2                                 22.693443
# 3                                 22.693443
# 4                                 22.693443
# 5                                 22.693443
# ...

# %% [markdown]
# #### Question 3 - Is your proposed method from Question 2 appropriate in this case? Why or why not?

# %% [markdown]
# I believe it is appropriate, because by taking the mean in a column that is not missing a whole lot of values, we may be able to see a value that may be more accurate. In addition, it is a numerical column so mean or median would be the best solution. The reason I took mean over median is that there does not appear to be extreme outliers that would influence the mean drastically.

# %% [markdown]
# #### Question 4 - Using the original dataframe (unchanged from Questoins 2, 3), create a mapping for the "Punxsutawney Phil" column which changes the categories into numerical quantities. For example: 'No Record' can be 0, 'No Shadow' can be 1, 'Partial Shadow' can be 2, and 'Full Shadow' can be 3. You should create the mapping *and* apply it to the data set by adding a new column called "Shadow".

# %%
maps = df['Punxsutawney Phil'].map({'No Record': 0, 'No Shadow': 1, 'Partial Shadow': 2, 'Full Shadow': 3})
df['Shadow'] = maps
df.head(10)
# Out:
#    Year Punxsutawney Phil  February Average Temperature  \
# 0  1886         No Record                           NaN
# 1  1887       Full Shadow                           NaN
# 2  1888       Full Shadow                           NaN
# 3  1889         No Record                           NaN
# 4  1890         No Shadow                           NaN
# 5  1891         No Record                           NaN
# 6  1892         No Record                           NaN
# 7  1893         No Record                           NaN
# 8  1894         No Record                           NaN
# 9  1895         No Record                          26.6
#
#    February Average Temperature (Northeast)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# ...

# %% [markdown]
# #### Question 5 - For all rows which have no record, remove the rows which have empty values in all of the quantitative columns. (Only 6 should be removed.)

# %%
check_df = df.loc[(df['February Average Temperature'].isnull()) & (df['February Average Temperature (Northeast)'].isnull()) & (df['February Average Temperature (Midwest)'].isnull()) & (df['February Average Temperature (Pennsylvania)'].isnull()) & (df['March Average Temperature'].isnull()) & (df['March Average Temperature (Northeast)'].isnull()) & (df['March Average Temperature (Midwest)'].isnull()) & (df['March Average Temperature (Pennsylvania)'].isnull())  ]
df = df.drop(check_df.index)
df.head(10)
# Out:
#     Year Punxsutawney Phil  February Average Temperature  \
# 9   1895         No Record                         26.60
# 10  1896         No Record                         35.04
# 11  1897         No Record                         33.39
# 12  1898       Full Shadow                         35.37
# 13  1899         No Record                         25.50
# 14  1900       Full Shadow                         30.76
# 15  1901       Full Shadow                         29.86
# 16  1902         No Record                         31.46
# 17  1903       Full Shadow                         28.42
# 18  1904       Full Shadow                         31.59
#
#     February Average Temperature (Northeast)  \
# 9                                       15.6
# 10                                      22.2
# 11                                      23.6
# 12                                      24.8
# 13                                      18.1
# 14                                      21.4
# ...

# %% [markdown]
# #### Question 6 - For the remaining rows which have no record (but the other columns *are* populated), determine an appropriate method for inputting the value for this column. Explain your reasoning, and show your work below (using pandas).

# %%
fullshadow = 0
fullFebAvg = 0
fullMarchAvg = 0
noshadow = 0
noFebAvg = 0
noMarchAvg = 0
partialshadow = 0
partialFebAvg = 0
partialMarchAvg = 0

full_shadow = df.loc[(df['Punxsutawney Phil'] == 'Full Shadow')]
no_shadow = df.loc[(df['Punxsutawney Phil'] == 'No Shadow')]
partial_shadow = df.loc[(df['Punxsutawney Phil'] == 'Partial Shadow')]

for item in df['Punxsutawney Phil']:
    if (item == 'No Shadow'):
        noshadow += 1
    elif (item == 'Partial Shadow'):
        partialshadow += 1
    elif (item == 'Full Shadow') :
        fullshadow += 1
        
print('Full Shadow: ', fullshadow, ',', 'No Shadow: ', ',', noshadow, 'Partial Shadow: ', partialshadow) 
    #new_dataset = df[['Year','Punxsutawney Phil', 'February Average Temperature', 'March Average Temperature']]
    
df3 = df.loc[(df['Punxsutawney Phil'] == 'No Record')]

fullFebAvg = full_shadow['February Average Temperature'].mean()
fullMarchAvg = full_shadow['March Average Temperature'].mean()

noFebAvg = no_shadow['February Average Temperature'].mean()
noMarchAvg = no_shadow['March Average Temperature'].mean()

partialFebAvg = partial_shadow['February Average Temperature'].mean()
partialMarchAvg = partial_shadow['March Average Temperature'].mean()
        
        
print('Full Shadow Feb Avg: ', fullFebAvg, ',', 'Full Shadow March Avg: ', fullMarchAvg)
print('No Shadow Feb Avg: ', noFebAvg, ',', 'No Shadow March Avg: ', noMarchAvg)
print('Partial Shadow Feb Avg: ', partialFebAvg, ',', 'Partial Shadow March Avg: ', partialMarchAvg)
# Out:
# Full Shadow:  100 , No Shadow:  , 15 Partial Shadow:  1
# Full Shadow Feb Avg:  33.7125 , Full Shadow March Avg:  41.6698
# No Shadow Feb Avg:  35.577999999999996 , No Shadow March Avg:  42.966
# Partial Shadow Feb Avg:  30.74 , Partial Shadow March Avg:  41.31

# %%
for items in df['Punxsutawney Phil']:
    df = df.replace('No Record', 'Full Shadow')
    maps = df['Punxsutawney Phil'].map({'No Record': 0, 'No Shadow': 1, 'Partial Shadow': 2, 'Full Shadow': 3})
    df['Shadow'] = maps
df.head(15)
# Out:
#     Year Punxsutawney Phil  February Average Temperature  \
# 9   1895       Full Shadow                         26.60
# 10  1896       Full Shadow                         35.04
# 11  1897       Full Shadow                         33.39
# 12  1898       Full Shadow                         35.37
# 13  1899       Full Shadow                         25.50
# 14  1900       Full Shadow                         30.76
# 15  1901       Full Shadow                         29.86
# 16  1902       Full Shadow                         31.46
# 17  1903       Full Shadow                         28.42
# 18  1904       Full Shadow                         31.59
# 19  1905       Full Shadow                         26.94
# 20  1906       Full Shadow                         33.69
# 21  1907       Full Shadow                         35.46
# 22  1908       Full Shadow                         33.01
# 23  1909       Full Shadow                         35.02
#
#     February Average Temperature (Northeast)  \
# ...

# %% [markdown]
# I have replaced all the No Record values with 'Full Shadow', as there are not many factors that help show a correlation or a pattern when it comes to seperating all the types. I have printed the averages for each, and the ranges are too varied within each. Partial Shadow only has 1 value as determined by the counter, so it is hard to say that other No Record values could be assigned to it.
#
# I have also updated the respective Shadows value with the value for Full Shadow, 3.

# %% [markdown]
# #### Question 7 - If we are trying to write a machine learning program which predicts the type of shadow for the year, which column(s) should be the independent variables X? Why?
#
# #### Use pandas to assign a variable X to be all of the rows of the data set with the column(s) that represent the independent variables.

# %% [markdown]
# Independent Variables (X): Punxsutawney Phil, February Average Temperature, February Average Temperature (Northeast), February Average Temperature (Midwest), February Average Temperature (Pennsylvania), March Average Temperature, March Average Temperature (Northeast), March Average Temperature (Midwest), March Average Temperature (Pennsylvania)
#
# The rows that I've assigned to the X variable are all of the numerical data points for the February and March Averages. This is because we can use these averages to try to see if there is a pattern for the shadow for that year. The one that has the shadows in word is also there, so we can see what the other years have historically had.

# %%
X= df.iloc[:,1:-1].values
print(X)
# Out:
# [['Full Shadow' 26.6 15.6 ... 27.6 40.2 31.3]
#  ['Full Shadow' 35.04 22.2 ... 25.3 36.9 27.8]
#  ['Full Shadow' 33.39 23.6 ... 32.0 44.0 36.9]
#  ...
#  ['Full Shadow' 32.13 21.0 ... 26.0 38.0 30.3]
#  ['Full Shadow' 32.99 12.1 ... 27.8 41.6 31.6]
#  ['No Shadow' 39.47 28.1 ... 38.8 49.5 43.4]]

# %% [markdown]
# #### Question 8 - If we are trying to write a machine learning program which predicts the type of shadow for the year, which column(s) should be the dependent variables Y? Why?
#
# #### Use pandas to assign a variable Y to be all of the rows of the data set with the column(s) that represent the dependent variables.

# %% [markdown]
# Dependent Variables (Y): Shadow
#
# This is the column we are trying to pick, which means it is dependent on the X values. I picked the Shadow column over the Punxsutawney Phil column as it is numerical data and may be easier to work with.

# %%
Y = df.iloc[:,10].values
print(Y)
# Out:
# [3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 3 1 3 3 3 3 3 3 3 2 3 3 3 3 3 3 3 1 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3 3
#  3 1 3 3 3 3 1 3 3 3 3 3 3 3 1 3 3 1 3 1 3 1 3 3 3 3 1 3 1 3 1 3 3 3 3 3 3
#  3 1 3 3 3 1 3 1 3 3 1]

# %% [markdown]
# #### Question 9 - Using the train_test_split function from the sklearn module, use a 70/30 split validation to split the data set into train and test. If you follow the example at the following link: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# Note: It's common practice to use the following variable names for unpacking the result:
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=(YOUR VALUE))
#
# sklearn will create a proper split where the following statements hold true:
# X_train is your train set independent variables
# Y_train is your train set dependent variables
# X_test is your test set independent variables
# Y_test is your test set dependent variables

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %% [markdown]
# #### Question 10 - Should the number of rows in X_train == number of rows in Y_train? Also, should the number of rows in X_test == Y_test? Why or why not? Validate your answer with code below:

# %% [markdown]
# Yes, because the amount of rows going into both variables is the same, the only thing that changes is the amount of columns.

# %%
xtrainlen = X_train.shape
ytrainlen = Y_train.shape

xtestlen = X_test.shape
ytestlen = Y_test.shape

print('X_Train Length:', xtrainlen, ',', 'Y_Train Length:', ytrainlen)
print('X_Test Length:', xtestlen, ',', 'Y_Test Length:', ytestlen)
# Out:
# X_Train Length: (85, 9) , Y_Train Length: (85,)
# X_Test Length: (37, 9) , Y_Test Length: (37,)
